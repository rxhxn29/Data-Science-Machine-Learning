# %% [markdown]
# <a href="https://colab.research.google.com/github/rxhxn29/Data-Science-Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Pandas Library:
# Useful for Data Processing & Analysis
# ## Pandas Data Frame:
# Pandas DataFrame is two-dimensional tabular data structure with labeled axes (rows and columns).

# %%
import pandas as pd

# %% [markdown]
# ## Creating pandas datafARAME

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing(as_frame=True)

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing)
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
housing_df = pd.DataFrame(housing.data,columns = housing.feature_names)

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_df.shape
# Out:
# (20640, 8)

# %% [markdown]
# ## Improting data Form CSV file to Pandas DataFrame

# %%
diabetes = pd.read_csv('diabetes.csv')

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(diabetes)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes.shape
# Out:
# (768, 9)

# %% [markdown]
# ## Loading the data from Excel file to pandas data frame

# %%
# pd.read_excel("file parth")

# %% [markdown]
# ## Exporting Data Frame To csv file

# %%
housing_df.to_csv('housing.csv')

# %% [markdown]
# ## Exporting Pandas Data Frame to a Excel File

# %%
#pd.to_excel('file_name.xlsx')

# %% [markdown]
# ### Crating data frame with random values

# %%
import numpy as np
random_df=pd.DataFrame(data=np.random.rand(20,10))

# %%
print(random_df)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.243691  0.364618  0.954695  0.594425  0.305436  0.504512  0.463853
# 1   0.799799  0.737203  0.013791  0.317848  0.462810  0.152307  0.492880
# 2   0.085065  0.264456  0.827469  0.362780  0.553723  0.720976  0.074952
# 3   0.757168  0.446108  0.589640  0.245862  0.899822  0.590500  0.230647
# 4   0.000522  0.654618  0.861952  0.340034  0.415382  0.086528  0.930489
# 5   0.561063  0.681595  0.026793  0.004801  0.858701  0.746884  0.175051
# 6   0.247300  0.453277  0.831876  0.995476  0.894076  0.390317  0.748977
# 7   0.855521  0.592010  0.250225  0.751416  0.036358  0.340491  0.514082
# 8   0.588403  0.272552  0.332488  0.734902  0.235937  0.249137  0.878192
# 9   0.206662  0.093520  0.962782  0.958631  0.301157  0.602802  0.367052
# 10  0.859623  0.507647  0.690984  0.291743  0.777667  0.817313  0.498318
# 11  0.591466  0.636169  0.778251  0.835287  0.407674  0.709126  0.589071
# ...

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.243691  0.364618  0.954695  0.594425  0.305436  0.504512  0.463853
# 1  0.799799  0.737203  0.013791  0.317848  0.462810  0.152307  0.492880
# 2  0.085065  0.264456  0.827469  0.362780  0.553723  0.720976  0.074952
# 3  0.757168  0.446108  0.589640  0.245862  0.899822  0.590500  0.230647
# 4  0.000522  0.654618  0.861952  0.340034  0.415382  0.086528  0.930489
#
#           7         8         9
# 0  0.624538  0.935271  0.536127
# 1  0.900698  0.305550  0.221762
# 2  0.664026  0.808690  0.270595
# 3  0.869308  0.821031  0.234999
# 4  0.903111  0.868814  0.970955

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# ## Inspecting Data Frame

# %%
#finding no of rows and coluums
housing_df.shape
# Out:
# (20640, 8)

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
# INFO ABOUT DATA FRAME HOUSING

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
#find the num of missing values
housing_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Counting the valus on based on lables

# %%
diabetes.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 38    16
# 36    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 44     8
# 51     8
# 50     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 53     5
# 57     5
# 48     5
# 60     5
# 55     4
# 63     4
# 62     4
# 66     4
# 56     3
# 65     3
# 59     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# Name: count, dtype: int64

# %%
#group the values based on ther mean
diabetes.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# ## Statistical Measures

# %%
#counts the no of values

# %%
housing_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
#mean Values Colums wise
housing_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
#standard deviation column wise
housing_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
#mim value in each colums
housing_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
#max value
housing_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
#all the statistical about the data
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# ## Manipulating a dataframe

# %%
#add colums in data frame
housing_df['price']= housing.target

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['MedInc'].plot(kind='hist', bins=20, title='MedInc')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['HouseAge'].plot(kind='hist', bins=20, title='HouseAge')
# ...

# %%
#removing Row
housing_df.drop(index=0,axis=0) # for row axis is 0 and for columes 1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
#droping colums
housing_df.drop(columns='price',axis=1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
#locating a row using the index value
housing_df.iloc[10]
# Out:
# MedInc          3.203100
# HouseAge       52.000000
# AveRooms        5.477612
# AveBedrms       1.079602
# Population    910.000000
# AveOccup        2.263682
# Latitude       37.850000
# Longitude    -122.260000
# price           2.815000
# Name: 10, dtype: float64

# %%
#locating perticular colums
print(housing_df.iloc[:,5])
# Out:
# 0        2.555556
# 1        2.109842
# 2        2.802260
# 3        2.547945
# 4        2.181467
#            ...
# 20635    2.560606
# 20636    3.122807
# 20637    2.325635
# 20638    2.123209
# 20639    2.616981
# Name: AveOccup, Length: 20640, dtype: float64

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      56         try:
# ---> 57             return self[key]
#      58         except KeyError:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_bunch.py in __getitem__(self, key)
#      41             )
# ---> 42         return super().__getitem__(key)
#      43
#
# KeyError: 'corr'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-58-1598269145.py in <cell line: 0>()
# ----> 1 housing.corr()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      57             return self[key]
#      58         except KeyError:
# ---> 59             raise AttributeError(key)
# ...

# %% [markdown]
# # -----end-----
