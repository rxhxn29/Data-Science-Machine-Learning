# %% [markdown]
# <a href="https://colab.research.google.com/github/rxhxn29/Data-Science-Machine-Learning/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib:
# • Useful for making Plots

# %%
import matplotlib.pyplot as plt

# %%
|!pip install matplotlib

# %%
import numpy as np

# %%
x= np.linspace(0,10,100)

# %%
y= np.sin(x)
z=np.cos(x)
print(x,y,z)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %% [markdown]
# # Plot the data

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
#adding title to x and y axis
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('x')
plt.ylabel('y and z')
plt.title("test")
plt.show()

# %%
#ploting Parabola
x =np.linspace(-10,10,100)
y=x**2
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"r+")
plt.show()

# %% [markdown]
# ## Bar plots

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
fig2 = plt.figure()
ax2 = fig2.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax2.pie(students,labels=langs,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b6999377450>,
# ...
#  [Text(0.8934077317878253, 0.6417340763756694, 'C'),
#   Text(-0.14850011851196682, 1.0899301421659702, 'C++'),
#   Text(-1.0995966178558083, 0.029787212022402733, 'Java'),
#   Text(0.14850021379668932, -1.089930129183673, 'Python'),
#   Text(1.042418607175302, -0.3512313303432699, 'PHP')],
#  [Text(0.48731330824790464, 0.3500367689321832, '19.83%'),
#   Text(-0.08100006464289097, 0.5945073502723472, '14.66%'),
#   Text(-0.5997799733758954, 0.016247570194037855, '30.17%'),
#   Text(0.08100011661637598, -0.5945073431910942, '25.00%'),
#   Text(0.5685919675501647, -0.19158072564178358, '10.34%')])

# %% [markdown]
# ## Scatter Plot

# %%
x = np.linspace(0,10,100)
y= np.sin(x)
z=np.cos(x)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## 3D scatter graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
z=np.linspace(0,15,1000)
x=np.sin(z)
y=np.cos(z)
ax.scatter(x,y,z,c=z,cmap='Greens')
plt.show()
